# %%
# import libraries
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
# Out:
# VBox()
# Starting Spark application
# <table>
# <tbody><tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>0</td><td>application_1737816386143_0001</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-10-0-14-79.us-east-2.compute.internal:20888/proxy/application_1737816386143_0001/" class="emr-proxy-link j-53QGNW6HO358 application_1737816386143_0001" emr-resource="j-53QGNW6HO358
# " application-id="application_1737816386143_0001">Link</a></td><td><a target="_blank" href="http://ip-10-0-8-225.us-east-2.compute.internal:8042/node/containerlogs/container_1737816386143_0001_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></tbody></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# ...

# %%
# %%bash
# # download data and copy to our s3 raw bucket
# wget -O - https://redfin-public-data.s3.us-west-2.amazonaws.com/redfin_market_tracker/city_market_tracker.tsv000.gz | aws s3 cp - s3://s3-mdesafari-raw-data/city_market_tracker.tsv000.gz
# Out:
# --2025-01-25 15:12:14--  https://redfin-public-data.s3.us-west-2.amazonaws.com/redfin_market_tracker/city_market_tracker.tsv000.gz
# Resolving redfin-public-data.s3.us-west-2.amazonaws.com (redfin-public-data.s3.us-west-2.amazonaws.com)... 52.92.162.178, 52.218.182.145, 52.92.192.210, ...
# Connecting to redfin-public-data.s3.us-west-2.amazonaws.com (redfin-public-data.s3.us-west-2.amazonaws.com)|52.92.162.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1331927109 (1.2G) [application/x-www-form-urlencoded]
# Saving to: ‘STDOUT’
#
#      0K .......... .......... .......... .......... ..........  0% 1.00M 21m10s
#     50K .......... .......... .......... .......... ..........  0% 1.00M 21m10s
#    100K .......... .......... .......... .......... ..........  0%  188M 14m9s
#    150K .......... .......... .......... .......... ..........  0% 1.01M 15m52s
#    200K .......... .......... .......... .......... ..........  0%  184M 12m43s
# ...
